# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
df_train = pd.read_excel('Data_Train.xlsx')
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_test = pd.read_excel('Test_set.xlsx')
df_test.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df_final = pd.concat([df_train,df_test])
df_final.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info   Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info  3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info  7662.0

# %%
df_final.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df_final.drop('Route',axis=1,inplace=True)
df_final.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1  Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
#
#   Duration Total_Stops Additional_Info   Price
# 0   2h 50m    non-stop         No info  3897.0
# 1   7h 25m     2 stops         No info  7662.0

# %%
df_final.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination Dep_Time  \
# 2666          Air India       6/06/2019  Kolkata    Banglore    20:30
# 2667             IndiGo      27/03/2019  Kolkata    Banglore    14:20
# 2668        Jet Airways       6/03/2019    Delhi      Cochin    21:50
# 2669          Air India       6/03/2019    Delhi      Cochin    04:00
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin    04:55
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667         16:55   2h 35m    non-stop         No info    NaN
# 2668  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669         19:15  15h 15m      1 stop         No info    NaN
# 2670         19:15  14h 20m      1 stop         No info    NaN

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
# dtypes: float64(1), object(9)
# memory usage: 1.1+ MB

# %%
df_final.Total_Stops
# Out:
# 0       non-stop
# 1        2 stops
# 2        2 stops
# 3         1 stop
# 4         1 stop
#           ...
# 2666      1 stop
# 2667    non-stop
# 2668      1 stop
# 2669      1 stop
# 2670      1 stop
# Name: Total_Stops, Length: 13354, dtype: object

# %%
df_final['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df_final['Total_Stops'] = df_final['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, 'nan':1, '4 stops':4})
df_final.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1    Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
# 2  Jet Airways       9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun
# 3       IndiGo      12/05/2019   Kolkata    Banglore    18:05         23:30
# 4       IndiGo      01/03/2019  Banglore   New Delhi    16:50         21:35
#
#   Duration  Total_Stops Additional_Info    Price
# 0   2h 50m          0.0         No info   3897.0
# 1   7h 25m          2.0         No info   7662.0
# 2      19h          2.0         No info  13882.0
# 3   5h 25m          1.0         No info   6218.0
# 4   4h 45m          1.0         No info  13302.0

# %%
df_final.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
df_final['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df_final['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df_final['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df_final['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
df_final['Airline'] = labelencoder.fit_transform(df_final['Airline'])
df_final['Source'] = labelencoder.fit_transform(df_final['Source'])
df_final['Destination'] = labelencoder.fit_transform(df_final['Destination'])
df_final['Additional_Info'] = labelencoder.fit_transform(df_final['Additional_Info'])
# Out:
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
df_final.head()
# Out:
#    Airline Date_of_Journey  Source  Destination Dep_Time  Arrival_Time  \
# 0        3      24/03/2019       0            5    22:20  01:10 22 Mar
# 1        1       1/05/2019       3            0    05:50         13:15
# 2        4       9/06/2019       2            1    09:25  04:25 10 Jun
# 3        3      12/05/2019       3            0    18:05         23:30
# 4        3      01/03/2019       0            5    16:50         21:35
#
#   Duration  Total_Stops  Additional_Info    Price
# 0   2h 50m          0.0                8   3897.0
# 1   7h 25m          2.0                8   7662.0
# 2      19h          2.0                8  13882.0
# 3   5h 25m          1.0                8   6218.0
# 4   4h 45m          1.0                8  13302.0

# %%
df_final['Date'] = df_final['Date_of_Journey'].str.split('/').str[0]
df_final['Month'] = df_final['Date_of_Journey'].str.split('/').str[1]
df_final['Year'] = df_final['Date_of_Journey'].str.split('/').str[2]

# %%
df_final['Date'] =df_final['Date'].astype(int)
df_final['Month'] =df_final['Month'].astype(int)
df_final['Year'] =df_final['Year'].astype(int)

# %%
df_final.drop('Date_of_Journey',axis=1, inplace= True)

# %%
df_final.head()
# Out:
#    Airline  Source  Destination Dep_Time  Arrival_Time Duration  Total_Stops  \
# 0        3       0            5    22:20  01:10 22 Mar   2h 50m          0.0
# 1        1       3            0    05:50         13:15   7h 25m          2.0
# 2        4       2            1    09:25  04:25 10 Jun      19h          2.0
# 3        3       3            0    18:05         23:30   5h 25m          1.0
# 4        3       0            5    16:50         21:35   4h 45m          1.0
#
#    Additional_Info    Price  Date  Month  Year
# 0                8   3897.0    24      3  2019
# 1                8   7662.0     1      5  2019
# 2                8  13882.0     9      6  2019
# 3                8   6218.0    12      5  2019
# 4                8  13302.0     1      3  2019

# %%
df_final['Dep_Hour'] = df_final['Dep_Time'].str.split(':').str[0]
df_final['Dep_Minute'] = df_final['Dep_Time'].str.split(':').str[0]

# %%
df_final['Dep_Hour']= df_final['Dep_Hour'].astype(int)
df_final['Dep_Minute']= df_final['Dep_Minute'].astype(int)

# %%
df_final.drop('Dep_Time',axis=1,inplace =True)
df_final.head()
# Out:
#    Airline  Source  Destination  Arrival_Time Duration  Total_Stops  \
# 0        3       0            5  01:10 22 Mar   2h 50m          0.0
# 1        1       3            0         13:15   7h 25m          2.0
# 2        4       2            1  04:25 10 Jun      19h          2.0
# 3        3       3            0         23:30   5h 25m          1.0
# 4        3       0            5         21:35   4h 45m          1.0
#
#    Additional_Info    Price  Date  Month  Year  Dep_Hour  Dep_Minute
# 0                8   3897.0    24      3  2019        22          22
# 1                8   7662.0     1      5  2019         5           5
# 2                8  13882.0     9      6  2019         9           9
# 3                8   6218.0    12      5  2019        18          18
# 4                8  13302.0     1      3  2019        16          16

# %%
df_final['Arrival_Hour']=df_final['Arrival_Time'].str.split(':').str[0]
df_final['Arrival_Minute']=df_final['Arrival_Time'].str.split(':').str[0]
df_final['Arrival_Hour']=df_final['Arrival_Hour'].astype(int)
df_final['Arrival_Minute']=df_final['Arrival_Minute'].astype(int)

# %%
df_final.drop('Arrival_Time',axis=1,inplace=True)

# %%
df_final.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5   2h 50m          0.0                8
# 1        1       3            0   7h 25m          2.0                8
# 2        4       2            1      19h          2.0                8
# 3        3       3            0   5h 25m          1.0                8
# 4        3       0            5   4h 45m          1.0                8
#
#      Price  Date  Month  Year  Dep_Hour  Dep_Minute  Arrival_Hour  \
# 0   3897.0    24      3  2019        22          22             1
# 1   7662.0     1      5  2019         5           5            13
# 2  13882.0     9      6  2019         9           9             4
# 3   6218.0    12      5  2019        18          18            23
# 4  13302.0     1      3  2019        16          16            21
#
#    Arrival_Minute
# 0               1
# 1              13
# 2               4
# 3              23
# 4              21

# %%
df_final['Duration']=df_final['Duration'].str.split(' ').str[0]

# %%
df_final.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5       2h          0.0                8
# 1        1       3            0       7h          2.0                8
# 2        4       2            1      19h          2.0                8
# 3        3       3            0       5h          1.0                8
# 4        3       0            5       4h          1.0                8
#
#      Price  Date  Month  Year  Dep_Hour  Dep_Minute  Arrival_Hour  \
# 0   3897.0    24      3  2019        22          22             1
# 1   7662.0     1      5  2019         5           5            13
# 2  13882.0     9      6  2019         9           9             4
# 3   6218.0    12      5  2019        18          18            23
# 4  13302.0     1      3  2019        16          16            21
#
#    Arrival_Minute
# 0               1
# 1              13
# 2               4
# 3              23
# 4              21

# %%
df_final['Duration']=df_final['Duration'].str.split('h').str[0]
df_final.head()
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5        2          0.0                8
# 1        1       3            0        7          2.0                8
# 2        4       2            1       19          2.0                8
# 3        3       3            0        5          1.0                8
# 4        3       0            5        4          1.0                8
#
#      Price  Date  Month  Year  Dep_Hour  Dep_Minute  Arrival_Hour  \
# 0   3897.0    24      3  2019        22          22             1
# 1   7662.0     1      5  2019         5           5            13
# 2  13882.0     9      6  2019         9           9             4
# 3   6218.0    12      5  2019        18          18            23
# 4  13302.0     1      3  2019        16          16            21
#
#    Arrival_Minute
# 0               1
# 1              13
# 2               4
# 3              23
# 4              21

# %%
df_final.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Dep_Hour              0
# Dep_Minute            0
# Arrival_Hour          0
# Arrival_Minute        0
# dtype: int64

# %%
df_final['Duration']=df_final['Duration'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 34 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X50sdW50aXRsZWQ%3D?line=0'>1</a> df_final['Duration']=df_final['Duration'].astype(int)
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\spoorthi.sheregar\AppData\Local\Continuum\anaconda3\envs\sp_env_ml\lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '5m'

# %%
df_final[df_final['Duration'] =='5m']
# Out:
#       Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 6474        1       4            3       5m          2.0                8
# 2660        1       4            3       5m          2.0                8
#
#         Price  Date  Month  Year  Dep_Hour  Dep_Minute  Arrival_Hour  \
# 6474  17327.0     6      3  2019        16          16            16
# 2660      NaN    12      3  2019        16          16            16
#
#       Arrival_Minute
# 6474              16
# 2660              16

# %%
df_final.drop(6474,axis = 0, inplace = True)
df_final.drop(2660,axis = 0, inplace = True)

# %%
df_final.head(2)
# Out:
#    Airline  Source  Destination Duration  Total_Stops  Additional_Info  \
# 0        3       0            5        2          0.0                8
# 1        1       3            0        7          2.0                8
#
#     Price  Date  Month  Year  Dep_Hour  Dep_Minute  Arrival_Hour  \
# 0  3897.0    24      3  2019        22          22             1
# 1  7662.0     1      5  2019         5           5            13
#
#    Arrival_Minute
# 0               1
# 1              13

# %%
df_final['Duration']=df_final['Duration'].astype(int)

# %%
pd.get_dummies(df_final, columns=['Airline','Source','Destination','Additional_Info' ],drop_first= True)
# Out:
#       Duration  Total_Stops    Price  Date  Month  Year  Dep_Hour  Dep_Minute  \
# 0            2          0.0   3897.0    24      3  2019        22          22
# 1            7          2.0   7662.0     1      5  2019         5           5
# 2           19          2.0  13882.0     9      6  2019         9           9
# 3            5          1.0   6218.0    12      5  2019        18          18
# 4            4          1.0  13302.0     1      3  2019        16          16
# ...        ...          ...      ...   ...    ...   ...       ...         ...
# 2666        23          1.0      NaN     6      6  2019        20          20
# 2667         2          0.0      NaN    27      3  2019        14          14
# 2668         6          1.0      NaN     6      3  2019        21          21
# 2669        15          1.0      NaN     6      3  2019         4           4
# 2670        14          1.0      NaN    15      6  2019         4           4
#
#       Arrival_Hour  Arrival_Minute  ...  Destination_5  Additional_Info_1  \
# 0                1               1  ...           True              False
# 1               13              13  ...          False              False
# 2                4               4  ...          False              False
# 3               23              23  ...          False              False
# 4               21              21  ...           True              False
# ...            ...             ...  ...            ...                ...
# 2666            20              20  ...          False              False
# 2667            16              16  ...          False              False
# 2668             4               4  ...          False              False
# 2669            19              19  ...          False              False
# 2670            19              19  ...          False              False
#
#       Additional_Info_2  Additional_Info_3  Additional_Info_4  \
# 0                 False              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False              False
# 4                 False              False              False
# ...                 ...                ...                ...
# 2666              False              False              False
# 2667              False              False              False
# 2668              False              False              False
# 2669              False              False              False
# 2670              False              False              False
#
#       Additional_Info_5  Additional_Info_6  Additional_Info_7  \
# 0                 False              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False              False
# 4                 False              False              False
# ...                 ...                ...                ...
# 2666              False              False              False
# 2667              False              False              False
# 2668              False              False              False
# 2669              False              False              False
# 2670              False              False              False
#
#       Additional_Info_8  Additional_Info_9
# 0                  True              False
# 1                  True              False
# 2                  True              False
# 3                  True              False
# 4                  True              False
# ...                 ...                ...
# 2666               True              False
# 2667               True              False
# 2668               True              False
# 2669               True              False
# 2670               True              False
#
# [13351 rows x 39 columns]
